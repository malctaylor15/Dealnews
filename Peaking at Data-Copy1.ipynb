# %%
import sqlite3
import pandas as pd 
import numpy as np 

pd.set_option('max_colwidth', 300)
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 300)

# %% [markdown]
# ## Class Version

# %%
def parse_callout(raw_str):
    str1 = raw_str.replace('$', '').replace(',', '')
    try:
        out = float(str1)
    except:
        out = np.nan
    return(out)

# %%
def api_gb_func(df):
    out = {}
    out['Count'] = df.shape[0]
    out['# w/ $ callout'] = df['callout_parse'].notnull().sum()
    if df.shape[0] > 1:
        out['Avg Callout Price'] = np.round(df['callout_parse'].mean(), 2)
        out['Avg Callout Pct Diff'] = np.round(df['callout_diff_pct'].mean(), 2)
    else:
        out['Avg Callout Price'] = np.nan
        out['Avg Callout Pct Diff'] = np.nan
    
    return(pd.Series(out))

# %%
class DealnewsAnalyzer():
    
    def __init__(self):
        self.db_path = '/home/malcolm/Dealnews/dealnews.db'
        pass 
    
    def create_con(self):
        self.con = sqlite3.connect(self.db_path)
        self.cursor = con.cursor()
    
    def check_db_stats(self):
        tables = self.cursor.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
        tables = [x[0] for x in tables]
        print("Tables: ", tables)
        
        self.dn_items_schema = cursor.execute("pragma table_info(`dealnews items`)").fetchall()
        print("Dealnews items schema: ", dn_self.dn_items_schema)
        
        
    def get_items_table(self, where_clause=''):
        self.items = pd.read_sql('Select * from `Dealnews self.items` '+ where_clause, self.con)
        self.items['callout_parse'] = self.items['call_out'].apply(parse_callout)
        self.items['callout_compare_parse'] = self.items['call_out_comparison'].apply(parse_callout)
        parsed_cnt = self.items['callout_parse'].notnull().sum()
        parsed_pct = np.round(100*parsed_cnt/self.items.shape[0], 2)
        parse_compare_cnt = self.items['callout_compare_parse'].notnull().sum()
        print(f"Parsed: {parsed_cnt}, Parsed Pct: {parsed_pct}, Parse compare cnt: {parse_compare_cnt}")
        
    def filter_items(self):
        self.items_sm = self.items.drop_duplicates(subset=['headline'])
        self.items_sm = self.items_sm[self.items_sm['callout_parse'].notnull()]
        print(f"Keep {self.items_sm.shape[0]} ", np.round(100*self.items_sm.shape[0]/self.items.shape[0],2))
        
    def get_category_table(self):
        last_category_date = cursor.execute("select max(_dt_pulled) from `Category Info`")
        last_category_date = last_category_date.fetchall()[0][0]
        print(last_category_date)
        categories = pd.read_sql(f"select * from `Category Info` where _dt_pulled='{last_category_date}' ", con)
        category_ids_sm = categories[categories['level_0'] == 'category']
        category_ids_sm = category_ids_sm[['id_number', 'name', 'short_name']]
        
    def combine_items_category_names(self):
        self.items2 = pd.merge(self.items_sm, category_ids_sm
                  , left_on = 'category_id_0', right_on='id_number'
                  , how='left').drop(['id_number', 'short_name'], axis=1)\
            .rename({'name_x':'vendor name', 
                     'name_y':'category name'}, axis=1)
    
    def top_vendors(self):
        vendor_gb = self.items2.groupby('vendor name').apply(lambda x:api_gb_func(x))\
            .sort_values('Count', ascending=False)
        top_vendors = vendor_gb.sort_values('Count', ascending=False)[:10].index.tolist()
   
    def category_gb(self):
        cateogry_gb =  self.items2.groupby('category name').apply(lambda x:api_gb_func(x))\
            .sort_values('Count', ascending=False)
        cateogry_gb
        
    def vendor_category_pivot(self):
        self.items2['1'] = 1
        self.items2_sm = self.items2[self.items2['vendor name'].isin(top_vendors)]
        top_vendor_categories = pd.pivot_table(self.items2_sm, index = 'category name', columns='vendor name', values='1'
                      , aggfunc = np.sum, margins=True)\
            .sort_values('All', ascending=False).head(10)
        top_vendor_categories
        
    def excute(self):
        self.create_con()
        self.check_db_stats()
        self.get_items_

# %%
alayzer1 =

# %% [markdown]
# ## Peaking at the Structure

# %%
con = sqlite3.connect('dealnews.db')
cursor = con.cursor()

tables = cursor.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
tables = [x[0] for x in tables]
tables
# Out:
# ['Category Info', 'Category Summary', 'Dealnews Items']

# %%
cursor.execute("pragma table_info(`dealnews items`)").fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 0),
#  (1, 'headline', 'TEXT', 0, None, 0),
#  (2, 'brief_headline', 'TEXT', 0, None, 0),
#  (3, 'summary', 'TEXT', 0, None, 0),
#  (4, 'secondary_summary', 'TEXT', 0, None, 0),
#  (5, 'key_attribute', 'TEXT', 0, None, 0),
#  (6, 'brief_notes', 'TEXT', 0, None, 0),
#  (7, 'url', 'TEXT', 0, None, 0),
#  (8, 'display_date', 'TEXT', 0, None, 0),
#  (9, 'publish_datetime_ts', 'TEXT', 0, None, 0),
#  (10, 'update_datetime_ts', 'TEXT', 0, None, 0),
#  (11, 'expiration_datetime_ts', 'TEXT', 0, None, 0),
#  (12, 'last_verified_datetime_ts', 'TEXT', 0, None, 0),
#  (13, 'editors_choice', 'INTEGER', 0, None, 0),
#  (14, 'sponsored', 'INTEGER', 0, None, 0),
#  (15, 'expired', 'INTEGER', 0, None, 0),
#  (16, 'expires_today', 'INTEGER', 0, None, 0),
#  (17, 'exclusive', 'INTEGER', 0, None, 0),
#  (18, 'searchable', 'INTEGER', 0, None, 0),
#  (19, 'hotness', 'INTEGER', 0, None, 0),
#  (20, 'call_out', 'TEXT', 0, None, 0),
#  (21, 'call_out_comparison', 'TEXT', 0, None, 0),
#  (22, 'sub_call_out', 'TEXT', 0, None, 0),
#  (23, 'Coupon Code', 'TEXT', 0, None, 0),
#  (24, 'category_id_0', 'INTEGER', 0, None, 0),
#  (25, 'namepath_0', 'TEXT', 0, None, 0),
#  (26, 'ancestor_list_0', 'TEXT', 0, None, 0),
#  (27, 'category_id_1', 'TEXT', 0, None, 0),
#  (28, 'namepath_1', 'TEXT', 0, None, 0),
#  (29, 'ancestor_list_1', 'TEXT', 0, None, 0),
#  (30, 'vendor_id', 'INTEGER', 0, None, 0),
#  (31, 'name', 'TEXT', 0, None, 0),
#  (32, 'Image path', 'TEXT', 0, None, 0),
#  (33, 'API Feed', 'TEXT', 0, None, 0),
#  (34, 'API id_number', 'INTEGER', 0, None, 0),
#  (35, '_dt_pulled', 'TEXT', 0, None, 0)]

# %%
demo = pd.read_sql('Select * from `Dealnews Items` limit 10', con)
demo.head()
# Out:
#          id                                            headline  \
# 0  19319075                            Zippo Lighters at Amazon
# 1  19319108                     Staples Fitness Clearance Deals
# 2  19319048                  Yardistry Gazebo Mosquito Mesh Kit
# 3  19319087  Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set
# 4  19319186                   Coisum Memory Foam Contour Pillow
#
#                                                brief_headline  \
# 0          Zippo Lighters at Amazon: + free shipping w/ Prime
# 1           Staples Fitness Clearance Deals: Save on 20 items
# 2    Yardistry Gazebo Mosquito Mesh Kit from $250 for members
# 3  Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set for $30
# 4                   Coisum Memory Foam Contour Pillow for $17
#
#                                                                                                                  summary  \
# 0                 Save about 15% off or more on most Zippo items on offer, including fuel canisters, lighters, and more.
# 1                                        Save on a selection of medicine balls, speed ropes, resistance bands, and more.
# 2  While not all the sizes are readily available for comparison, you'd pay $50 more for the 12x12-ft. kit at Home Depot.
# 3                                                                     Apply coupon code "57QBJPCJ" for a savings of $30.
# 4                                                                     Apply coupon code "W4LI2ORT" for a savings of $18.
#
#                                                                                                                                                                                                                                                                                              secondary_summary  \
# 0  <div class="snippet summary" title="Save&#x20;about&#x20;15&#x25;&#x20;off&#x20;or&#x20;more&#x20;on&#x20;most&#x20;Zippo&#x20;items&#x20;on&#x20;offer,&#x20;including&#x20;fuel&#x20;canisters,&#x20;lighters,&#x20;and&#x20;more."> <p>Save about 15% off or more on most Zippo items on offer, inclu...
# 1  <div class="snippet summary" title="Save&#x20;on&#x20;a&#x20;selection&#x20;of&#x20;medicine&#x20;balls,&#x20;speed&#x20;ropes,&#x20;resistance&#x20;bands,&#x20;and&#x20;more."> <p>Save on a selection of medicine balls, speed ropes, resistance bands, and more. <a target="_blank" href="https://ww...
# 2  <div class="snippet summary" title="While&#x20;not&#x20;all&#x20;the&#x20;sizes&#x20;are&#x20;readily&#x20;available&#x20;for&#x20;comparison,&#x20;you&#x27;d&#x20;pay&#x20;&#x24;50&#x20;more&#x20;for&#x20;the&#x20;12x12-ft.&#x20;kit&#x20;at&#x20;Home&#x20;Depot."> <p>While not all the sizes are...
# 3  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;57QBJPCJ&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;30."> <p>Apply coupon code "57QBJPCJ" for a savings of $30. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
# 4  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;W4LI2ORT&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;18."> <p>Apply coupon code "W4LI2ORT" for a savings of $18. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
#
#   key_attribute  \
# 0        Amazon
# 1       Staples
# 2        Costco
# 3        Amazon
# 4        Amazon
#
#                                                                                                                                                                                                                         brief_notes  \
# 0                                                                                                                                                                   Pictured is the Zippo Matte Pocket Lighter for $15.93 ($6 off).
# 1       Pictured is the SPRI Xerball 4-Lb. Medicine Ball for $18.13 (low by $19). Shipping is free over $25 for Staples Rewards members. (It's free to join. Plus, you'll receive no minimum free shipping for the first 3 months.)
# 2                                                                                                                                                                    Free shipping. Non-members pay a 5% surcharge. Model: YM12938.
# 3  Free shipping. Available in Blank-Green. Sold by uxian via Amazon. <br><b>Features:</b> 3/4" brass connectors, 4 layer natural latex tube and includes hose, 9-mode spray nozzle, storage pouch, hanging hook, 2 rubber washers.
# 4                                                                     Free shipping. Sold by Maliton via Amazon. <br><b>Features:</b> for back and side sleepers, 60D memory foam, ergonomic design, washable cover and ventilated.
#
#                                                                                                                               url  \
# 0                          https://www.dealnews.com/Zippo-Lighters-at-Amazon-free-shipping-w-Prime/19319075.html?iref=site-widget
# 1          https://www.dealnews.com/Staples-Fitness-Clearance-Deals-Save-on-20-items-free-shipping/19319108.html?iref=site-widget
# 2                     https://www.dealnews.com/products/Yardistry/Yardistry-Gazebo-Mosquito-Mesh-Kit/230813.html?iref=site-widget
# 3  https://www.dealnews.com/Haliluya-100-Ft-5-in-1-Expandable-Garden-Hose-Set-for-30-free-shipping/19319087.html?iref=site-widget
# 4                  https://www.dealnews.com/Coisum-Memory-Foam-Contour-Pillow-for-17-free-shipping/19319186.html?iref=site-widget
#
#                     display_date  publish_datetime_ts   update_datetime_ts  \
# 0  Last verified 1 hr 19 min ago  2021-06-18 16:50:19  2021-06-18 18:02:29
# 1  Last verified 1 hr 15 min ago  2021-06-18 16:54:14  2021-06-18 18:02:28
# 2   Last verified 2 hr 1 min ago  2021-06-18 16:08:26  2021-06-18 18:02:35
# 3  Last verified 1 hr 23 min ago  2021-06-18 16:46:38  2021-06-18 18:02:30
# 4       Last verified 32 min ago  2021-06-18 17:37:49  2021-06-18 18:02:22
#
#   expiration_datetime_ts last_verified_datetime_ts  editors_choice  sponsored  \
# 0    1970-01-01 00:00:00       2021-06-18 16:50:19               0          0
# 1    1970-01-01 00:00:00       2021-06-18 16:54:14               0          0
# 2    1970-01-01 00:00:00       2021-06-18 16:08:25               0          0
# 3    2021-06-24 12:31:00       2021-06-18 16:46:37               0          0
# 4    2021-07-01 04:59:00       2021-06-18 17:37:48               0          0
#
#    expired  expires_today  exclusive  searchable  hotness  \
# 0        0              0          0           1        5
# 1        0              0          0           1        5
# 2        0              0          0           1        5
# 3        0              0          0           1        4
# 4        0              0          0           1        4
#
#                 call_out call_out_comparison            sub_call_out  \
# 0                                             free shipping w/ Prime
# 1       Save on 20 items                               free shipping
# 2  from $250 for members                               free shipping
# 3                    $30                 $60           free shipping
# 4                    $17                 $35           free shipping
#
#   Coupon Code  category_id_0 namepath_0 ancestor_list_0 category_id_1  \
# 0        None            197       None             196          None
# 1        None            655       None             211          None
# 2        None            744       None         196,198          None
# 3    57QBJPCJ            198       None             196          None
# 4    W4LI2ORT            638       None         196,360          None
#
#   namepath_1 ancestor_list_1  vendor_id     name  \
# 0       None            None        313   Amazon
# 1       None            None        274  Staples
# 2       None            None        897   Costco
# 3       None            None        313   Amazon
# 4       None            None        313   Amazon
#
#                                                                                                                 Image path  \
# 0                            /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Zippo Lighters at Amazon_19319075.jpg
# 1                     /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Staples Fitness Clearance Deals_19319108.jpg
# 2                  /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Yardistry Gazebo Mosquito Mesh Kit_19319048.jpg
# 3  /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set_19319087.jpg
# 4                   /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Coisum Memory Foam Contour Pillow_19319186.jpg
#
#                             API Feed  API id_number        _dt_pulled
# 0  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 1  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 2  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 3  Popularity Rank : Popularity: 4/5           1777  2021-06-18 18:10
# 4  Popularity Rank : Popularity: 4/5           1777  2021-06-18 18:10

# %%
num_deals = cursor.execute("select count(*) from `Dealnews Items`").fetchall()[0][0]
print(num_deals)
# assert(num_deals > 200000), f"Too many for memory? @ {num_deals}"
# Out:
# 66078

# %%
items = pd.read_sql('Select * from `Dealnews Items`', con)
items.head()
# Out:
#          id                                            headline  \
# 0  19319075                            Zippo Lighters at Amazon
# 1  19319108                     Staples Fitness Clearance Deals
# 2  19319048                  Yardistry Gazebo Mosquito Mesh Kit
# 3  19319087  Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set
# 4  19319186                   Coisum Memory Foam Contour Pillow
#
#                                                brief_headline  \
# 0          Zippo Lighters at Amazon: + free shipping w/ Prime
# 1           Staples Fitness Clearance Deals: Save on 20 items
# 2    Yardistry Gazebo Mosquito Mesh Kit from $250 for members
# 3  Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set for $30
# 4                   Coisum Memory Foam Contour Pillow for $17
#
#                                                                                                                  summary  \
# 0                 Save about 15% off or more on most Zippo items on offer, including fuel canisters, lighters, and more.
# 1                                        Save on a selection of medicine balls, speed ropes, resistance bands, and more.
# 2  While not all the sizes are readily available for comparison, you'd pay $50 more for the 12x12-ft. kit at Home Depot.
# 3                                                                     Apply coupon code "57QBJPCJ" for a savings of $30.
# 4                                                                     Apply coupon code "W4LI2ORT" for a savings of $18.
#
#                                                                                                                                                                                                                                                                                              secondary_summary  \
# 0  <div class="snippet summary" title="Save&#x20;about&#x20;15&#x25;&#x20;off&#x20;or&#x20;more&#x20;on&#x20;most&#x20;Zippo&#x20;items&#x20;on&#x20;offer,&#x20;including&#x20;fuel&#x20;canisters,&#x20;lighters,&#x20;and&#x20;more."> <p>Save about 15% off or more on most Zippo items on offer, inclu...
# 1  <div class="snippet summary" title="Save&#x20;on&#x20;a&#x20;selection&#x20;of&#x20;medicine&#x20;balls,&#x20;speed&#x20;ropes,&#x20;resistance&#x20;bands,&#x20;and&#x20;more."> <p>Save on a selection of medicine balls, speed ropes, resistance bands, and more. <a target="_blank" href="https://ww...
# 2  <div class="snippet summary" title="While&#x20;not&#x20;all&#x20;the&#x20;sizes&#x20;are&#x20;readily&#x20;available&#x20;for&#x20;comparison,&#x20;you&#x27;d&#x20;pay&#x20;&#x24;50&#x20;more&#x20;for&#x20;the&#x20;12x12-ft.&#x20;kit&#x20;at&#x20;Home&#x20;Depot."> <p>While not all the sizes are...
# 3  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;57QBJPCJ&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;30."> <p>Apply coupon code "57QBJPCJ" for a savings of $30. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
# 4  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot
# 0                                             free shipping w/ Prime
# 1       Save on 20 items                               free shipping
# 2  from $250 for members                               free shipping
# 3                    $30                 $60           free shipping
# 4                    $17                 $35           free shipping
#
#   Coupon Code  category_id_0 namepath_0 ancestor_list_0 category_id_1  \
# 0        None            197       None             196          None
# 1        None            655       None             211          None
# 2        None            744       None         196,198          None
# 3    57QBJPCJ            198       None             196          None
# 4    W4LI2ORT            638       None         196,360          None
#
#   namepath_1 ancestor_list_1  vendor_id     name  \
# 0       None            None      313.0   Amazon
# 1       None            None      274.0  Staples
# 2       None            None      897.0   Costco
# 3       None            None      313.0   Amazon
# 4       None            None      313.0   Amazon
#
#                                                                                                                 Image path  \
# 0                            /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Zippo Lighters at Amazon_19319075.jpg
# 1                     /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Staples Fitness Clearance Deals_19319108.jpg
# 2                  /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Yardistry Gazebo Mosquito Mesh Kit_19319048.jpg
# 3  /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Haliluya 100-Ft. 5-in-1 Expandable Garden Hose Set_19319087.jpg
# 4                   /home/malcolm/Demo with APIs/Dealnews Images/2021-06-18/Coisum Memory Foam Contour Pillow_19319186.jpg
#
#                             API Feed  API id_number        _dt_pulled
# 0  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 1  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 2  Popularity Rank : Popularity: 5/5           1774  2021-06-18 18:10
# 3  Popularity Rank : Popularity: 4/5           1777  2021-06-18 18:10
# 4  Popularity Rank : Popularity: 4/5           1777  2021-06-18 18:10

# %%
items.isna().sum()
# Out:
# id                               0
# headline                         0
# brief_headline                   0
# summary                          0
# secondary_summary                0
# key_attribute                    0
# brief_notes                      0
# url                              0
# display_date                     0
# publish_datetime_ts              0
# update_datetime_ts               0
# expiration_datetime_ts           0
# last_verified_datetime_ts        0
# editors_choice                   0
# sponsored                        0
# expired                          0
# expires_today                    0
# exclusive                        0
# searchable                       0
# hotness                          0
# call_out                         0
# call_out_comparison              0
# sub_call_out                  4302
# Coupon Code                  45500
# category_id_0                    0
# namepath_0                   66078
# ancestor_list_0               8887
# category_id_1                60678
# namepath_1                   66078
# ancestor_list_1              61625
# vendor_id                      257
# name                           257
# Image path                       0
# API Feed                         0
# API id_number                    0
# _dt_pulled                       0
# dtype: int64

# %% [markdown]
# ## Parse Callout (Prices and comparisons)

# %%
items[items['call_out'] == ''].shape
items[items['call_out_comparison'] == ''].shape
# Out:
# (19587, 36)

# %%
def parse_callout(raw_str):
    str1 = raw_str.replace('$', '').replace(',', '')
    try:
        out = float(str1)
    except:
        out = np.nan
    return(out)

# %%
items['callout_parse'] = items['call_out'].apply(parse_callout)
items['callout_compare_parse'] = items['call_out_comparison'].apply(parse_callout)
parsed_cnt = items['callout_parse'].notnull().sum()
parsed_pct = np.round(100*parsed_cnt/items.shape[0], 2)
parse_compare_cnt = items['callout_compare_parse'].notnull().sum()
print(f"Parsed: {parsed_cnt}, Parsed Pct: {parsed_pct}, Parse compare cnt: {parse_compare_cnt}")
# Out:
# Parsed: 44325, Parsed Pct: 67.08, Parse compare cnt: 46487

# %%
items['callout_diff'] = items['callout_compare_parse'] - items['callout_parse'] 
items['callout_diff_pct'] = np.round(100*(items['callout_compare_parse'] - items['callout_parse'])
                                     /items['callout_compare_parse'], 2)
pd.concat([items['callout_diff'].describe(), items['callout_diff_pct'].describe()],axis=1)
# Out:
#        callout_diff  callout_diff_pct
# count  42258.000000      42258.000000
# mean      71.003167         41.874419
# std      157.727094         18.825568
# min        0.010000          0.140000
# 25%       10.010000         27.270000
# 50%       25.000000         41.180000
# 75%       65.000000         53.570000
# max     7000.000000         99.850000

# %%
## Take a peak at one or 2
items.sort_values('publish_datetime_ts', ascending=False).head(10) # looking for url to compare
# Out:
#              id  \
# 66051  20121791
# 66041  20121776
# 66050  20121779
# 66037  20121758
# 66059  20121761
# 66043  20121713
# 66076  20097833
# 66046  20121647
# 66068  20121677
# 66063  20121707
#
#                                                                       headline  \
# 66051                        M-D Building Products 1/8" x 90-Ft. Caulking Cord
# 66041                                                     Crocs Clearance Sale
# 66050                                     Eahthni Cable Management Tray 2-Pack
# 66037  Southwire Romex SIMpull 25-Foot 14/2 NM-B Indoor Electrical Copper Wire
# 66059                                                    Ulta Spring Haul Sale
# 66043                       Eahthni Selfie Ring Light with Webcam/Phone Holder
# 66076                                                  Fidelity® Youth Account
# 66046                                  Eahthni Pet Nail Trimmer with LED Light
# 66068              Eathni Ring Light Video Conference Lighting Kit for Laptops
# 66063                                               Designer Watches at Macy's
#
#                                                                         brief_headline  \
# 66051                         M-D Building Products 1/8" x 90-Ft. Caulking Cord for $6
# 66041                                              Crocs Clearance Sale: Up to 50% off
# 66050                                     Eahthni Cable Management Tray 2-Pack for $10
# 66037  Southwire Romex SIMpull 25-Foot 14/2 NM-B Indoor Electrical Copper Wire for $16
# 66059                                             Ulta Spring Haul Sale: Up to 50% off
# 66043                       Eahthni Selfie Ring Light with Webcam/Phone Holder for $11
# 66076                         Fidelity® Youth Account: Get a $50 reward w/ new account
# 66046                                   Eahthni Pet Nail Trimmer with LED Light for $9
# 66068              Eathni Ring Light Video Conference Lighting Kit for Laptops for $10
# 66063                                       Designer Watches at Macy's: 40% to 60% off
#
#                                                                                                                                                                       summary  \
# 66051                                                                                                                                               It's $9 under list price.
# 66041                                                                                                               Save on sandals, clogs, Jibbitz, and more for the family.
# 66050                                                                                                                      Apply coupon code "807YO9KL" for a savings of $40.
# 66037  Like a bird on the wire, Like a drunk in a midnight choir, It has tried in its way to be free. (Well, it didn't quite manage "free", but it is a respectable $10 low.)
# 66059                                Save on makeup, skin care, hair care, styling tools, and more from brands like Tarte, L'Oreal, Milani, and Colourpop just to name a few.
# 66043                                                                                                                      Apply coupon code "807YO9KL" for a savings of $43.
# 66076
# 66046                                                                                                                      Apply coupon code "807YO9KL" for a savings of $36.
# 66068                                                                                                                      Apply coupon code "807YO9KL" for a savings of $40.
# 66063                                         Save on over 460 men's, women's, and kids' styles from brands like DKNY, Kate Spade New York, Michael Kors, and Tommy Hilfiger.
#
#                                                                                                                                                                                                                                                                                                  secondary_summary  \
# 66051  <div class="snippet summary" title="You&#x27;d&#x20;pay&#x20;&#x24;10&#x20;at&#x20;your&#x20;local&#x20;hardware&#x20;store."> <p>You'd pay $10 at your local hardware store. <a target="_blank" href="https://www.dealnews.com/lw/click.html?20,2,20121791,iref=site-widget">Buy Now at Amazon</a> </p>...
# 66041  <div class="snippet summary" title="Save&#x20;on&#x20;sandals,&#x20;clogs,&#x20;Jibbitz,&#x20;and&#x20;more&#x20;for&#x20;the&#x20;family."> <p>Save on sandals, clogs, Jibbitz, and more for the family. <a target="_blank" href="https://www.dealnews.com/lw/click.html?20,2,20121776,iref=site-widget...
# 66050  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;807YO9KL&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;40."> <p>Apply coupon code "807YO9KL" for a savings of $40. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
# 66037  <div class="snippet summary" title="Like&#x20;a&#x20;bird&#x20;on&#x20;the&#x20;wire,&#x20;Like&#x20;a&#x20;drunk&#x20;in&#x20;a&#x20;midnight&#x20;choir,&#x20;It&#x20;has&#x20;tried&#x20;in&#x20;its&#x20;way&#x20;to&#x20;be&#x20;free.&#x20;&#x28;Well,&#x20;it&#x20;didn&#x27;t&#x20;quite&#x20;ma...
# 66059  <div class="snippet summary" title="Save&#x20;on&#x20;makeup,&#x20;skin&#x20;care,&#x20;hair&#x20;care,&#x20;styling&#x20;tools,&#x20;and&#x20;more&#x20;from&#x20;brands&#x20;like&#x20;Tarte,&#x20;L&#x27;Oreal,&#x20;Milani,&#x20;and&#x20;Colourpop&#x20;just&#x20;to&#x20;name&#x20;a&#x20;few."> <...
# 66043  <div class="body-offer body-burst"> <div class="snippet summary" title="To&#x20;save&#x20;&#x24;43,&#x20;apply&#x20;coupon&#x20;code&#x20;&quot;807YO9KL&quot;."> <p>To save $43, apply coupon code "807YO9KL". <a target="_blank" href="https://www.dealnews.com/lw/click.html?20,2,20121713,iref=site-...
# 66076  <div class="snippet summary" title=""> <p> </p> </div> <div class="snippet features" title="Open&#x20;a&#x20;Fidelity&#x00AE;&#x20;Youth&#x20;Account&#x20;for&#x20;your&#x20;teen,&#x20;and&#x20;they&#x27;&#x27;ll&#x20;get&#x20;&#x24;50&#x20;dropped&#x20;into&#x20;their&#x20;account.&#x20;Your&#x...
# 66046  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;807YO9KL&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;36."> <p>Apply coupon code "807YO9KL" for a savings of $36. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
# 66068  <div class="body-offer body-burst"> <div class="snippet summary" title="Apply&#x20;coupon&#x20;code&#x20;&quot;807YO9KL&quot;&#x20;for&#x20;a&#x20;savings&#x20;of&#x20;&#x24;40."> <p>Apply coupon code "807YO9KL" for a savings of $40. <a target="_blank" href="https://www.dealnews.com/lw/click.htm...
# 66063  <div class="snippet summary" title="Save&#x20;on&#x20;over&#x20;460&#x20;men&#x27;s,&#x20;women&#x27;s,&#x20;and&#x20;kids&#x27;&#x20;styles&#x20;from&#x20;brands&#x20;like&#x20;DKNY,&#x20;Kate&#x20;Spade&#x20;New&#x20;York,&#x20;Michael&#x20;Kors,&#x20;and&#x20;Tommy&#x20;Hilfiger."> <p>Save on...
items[items['call_out'] == ''].shape
items[items['call_out_comparison'] == ''].shape
# Out:
# (19587, 36)

# %% [markdown]
# ### Filter for dups and items with callout numbers

# %%
items_sm = items.drop_duplicates(subset=['headline'])
items_sm = items_sm[items_sm['callout_parse'].notnull()]
print(f"Keep {items_sm.shape[0]} ", np.round(100*items_sm.shape[0]/items.shape[0],2))
items_sm.shape
# Out:
# Keep 29636  44.85
# (29636, 41)

# %%
items_sm.groupby('API Feed')['headline'].count()
# Out:
# API Feed
# Popularity Rank : Popularity: 1/5    3224
# Popularity Rank : Popularity: 2/5    6004
# Popularity Rank : Popularity: 3/5    9414
# Popularity Rank : Popularity: 4/5    8445
# Popularity Rank : Popularity: 5/5    2549
# Name: headline, dtype: int64

# %% [markdown]
# ## Get Category Lookup table

# %%
cat_0_deals = items_sm.groupby('category_id_0')['headline'].count().sort_values(ascending=False)
cat_0_deals = cat_0_deals.reset_index().rename({'headline':'# of deals'}, axis=1)
cat_0_deals
# Out:
#      category_id_0  # of deals
# 0              280        1412
# 1              226        1187
# 2              201        1173
# 3               49         811
# 4              197         695
# ..             ...         ...
# 344            209           1
# 345            210           1
# 346           1057           1
# 347            299           1
# 348            305           1
#
# [349 rows x 2 columns]

# %%
last_category_date = cursor.execute("select max(_dt_pulled) from `Category Info`")
last_category_date = last_category_date.fetchall()[0][0]
print(last_category_date)
categories = pd.read_sql(f"select * from `Category Info` where _dt_pulled='{last_category_date}' ", con)
categories
# Out:
# 2022-04-15 15:37
#       level_0  level_1               name  count  id_number  \
# 0      vendor        0             Amazon    854        313
# 1      vendor        1               eBay    152         50
# 2      vendor        2             Macy's     64        288
# 3      vendor        3            Walmart     63        321
# 4      vendor        4         Home Depot     44        958
# ..        ...      ...                ...    ...        ...
# 881  category       21          Groceries      1        214
# 882  category       22     Toys & Hobbies      1        226
# 883  category       23         Bed & Bath      1        360
# 884  category       24  Computer Services      1        440
# 885  category       25    Patio Furniture      1        744
#
#             short_name      id_name        _dt_pulled
# 0               Amazon    vendor_id  2022-04-15 15:37
# 1                 eBay    vendor_id  2022-04-15 15:37
# 2               Macy's    vendor_id  2022-04-15 15:37
# 3              Walmart    vendor_id  2022-04-15 15:37
# 4           Home Depot    vendor_id  2022-04-15 15:37
# ..                 ...          ...               ...
# 881          Groceries  category_id  2022-04-15 15:37
# 882     Toys & Hobbies  category_id  2022-04-15 15:37
# 883         Bed & Bath  category_id  2022-04-15 15:37
# 884  Computer Services  category_id  2022-04-15 15:37
# 885    Patio Furniture  category_id  2022-04-15 15:37
#
# [886 rows x 8 columns]

# %%
category_ids_sm = categories[categories['level_0'] == 'category']
category_ids_sm = category_ids_sm[['id_number', 'name', 'short_name']]
category_ids_sm
# Out:
#      id_number                       name                 short_name
# 860        196              Home & Garden              Home & Garden
# 861        202     Clothing & Accessories     Clothing & Accessories
# 862        142                Electronics                Electronics
# 863         39                  Computers                  Computers
# 864        211           Sports & Fitness           Sports & Fitness
# 865         40               Store Events               Store Events
# 866        756            Health & Beauty            Health & Beauty
# 867        186              Gaming & Toys              Gaming & Toys
# 868        182   Office & School Supplies   Office & School Supplies
# 869        238                 Automotive                 Automotive
# 870        178       Movies, Music, Books       Movies, Music, Books
# 871        206     Travel & Entertainment     Travel & Entertainment
# 872        636           Special Occasion           Special Occasion
# 873        859                 Gift Cards                 Gift Cards
# 874        702         Financial Services         Financial Services
# 875        706                      Local                      Local
# 876        500  Movies, TV Shows & Videos  Movies, TV Shows & Videos
# 877        209                Car Rentals                Car Rentals
# 878         75                   Monitors                   Monitors
# 879        174                Cell Phones                Cell Phones
# 880        213               Food & Drink               Food & Drink
# 881        214                  Groceries                  Groceries
# 882        226             Toys & Hobbies             Toys & Hobbies
# 883        360                 Bed & Bath                 Bed & Bath
# 884        440          Computer Services          Computer Services
# 885        744            Patio Furniture            Patio Furniture

# %%
pd.merge(cat_0_deals, category_ids_sm, left_on ='category_id_0', right_on='id_number')
# Out:
#     category_id_0  # of deals  id_number                       name  \
# 0             226        1187        226             Toys & Hobbies
# 1             238         618        238                 Automotive
# 2             196         591        196              Home & Garden
# 3             214         292        214                  Groceries
# 4             360         254        360                 Bed & Bath
# 5             211         209        211           Sports & Fitness
# 6              75         204         75                   Monitors
# 7             744         148        744            Patio Furniture
# 8             202          90        202     Clothing & Accessories
# 9             142          59        142                Electronics
# 10            859          52        859                 Gift Cards
# 11            182          49        182   Office & School Supplies
# 12            213          38        213               Food & Drink
# 13             40          25         40               Store Events
# 14            186          24        186              Gaming & Toys
# 15            756          20        756            Health & Beauty
# 16            500          10        500  Movies, TV Shows & Videos
# 17            206           7        206     Travel & Entertainment
# 18            174           5        174                Cell Phones
# 19            178           4        178       Movies, Music, Books
# 20             39           2         39                  Computers
# 21            209           1        209                Car Rentals
#
#                    short_name
# 0              Toys & Hobbies
# 1                  Automotive
# 2               Home & Garden
# 3                   Groceries
# 4                  Bed & Bath
# 5            Sports & Fitness
# 6                    Monitors
# 7             Patio Furniture
# 8      Clothing & Accessories
# 9                 Electronics
# 10                 Gift Cards
# 11   Office & School Supplies
# 12               Food & Drink
# 13               Store Events
# 14              Gaming & Toys
# 15            Health & Beauty
# 16  Movies, TV Shows & Videos
# 17     Travel & Entertainment
# 18                Cell Phones
# 19       Movies, Music, Books
# 20                  Computers
# 21                Car Rentals

# %%
items.columns
# Out:
# Index(['id', 'headline', 'brief_headline', 'summary', 'secondary_summary',
#        'key_attribute', 'brief_notes', 'url', 'display_date',
#        'publish_datetime_ts', 'update_datetime_ts', 'expiration_datetime_ts',
#        'last_verified_datetime_ts', 'editors_choice', 'sponsored', 'expired',
#        'expires_today', 'exclusive', 'searchable', 'hotness', 'call_out',
#        'call_out_comparison', 'sub_call_out', 'Coupon Code', 'category_id_0',
#        'namepath_0', 'ancestor_list_0', 'category_id_1', 'namepath_1',
#        'ancestor_list_1', 'vendor_id', 'name', 'Image path', 'API Feed',
#        'API id_number', '_dt_pulled', 'callout_compare_parse', 'callout_parse',
#        'callout_diff', 'callout_diff_pct'],
#       dtype='object')

# %% [markdown]
# ## Callout Differences

# %%
def api_gb_func(df):
    out = {}
    out['Count'] = df.shape[0]
    out['# w/ $ callout'] = df['callout_parse'].notnull().sum()
    if df.shape[0] > 1:
        out['Avg Callout Price'] = np.round(df['callout_parse'].mean(), 2)
        out['Avg Callout Pct Diff'] = np.round(df['callout_diff_pct'].mean(), 2)
    else:
        out['Avg Callout Price'] = np.nan
        out['Avg Callout Pct Diff'] = np.nan
    
    return(pd.Series(out))

# %%
api_feed_gb = items_sm.groupby('API Feed').apply(lambda x:api_gb_func(x))
# api_feed_gb['Pct w callout'] = np.round(100*api_feed_gb['# w/ $ callout']/api_feed_gb['Count'], 2) 
api_feed_gb['Count Ratio to Max'] = np.round(api_feed_gb['Count']/api_feed_gb['Count'].max(),2)
api_feed_gb
# Out:
#                                     Count  # w/ $ callout  Avg Callout Price  \
# API Feed
# Popularity Rank : Popularity: 1/5  3224.0          3224.0             162.94
# Popularity Rank : Popularity: 2/5  6004.0          6004.0             164.96
# Popularity Rank : Popularity: 3/5  9414.0          9414.0             103.78
# Popularity Rank : Popularity: 4/5  8445.0          8445.0              79.59
# Popularity Rank : Popularity: 5/5  2549.0          2549.0              58.71
#
#                                    Avg Callout Pct Diff  Pct w callout  \
# API Feed
# Popularity Rank : Popularity: 1/5                 35.82          100.0
# Popularity Rank : Popularity: 2/5                 36.39          100.0
# Popularity Rank : Popularity: 3/5                 41.22          100.0
# Popularity Rank : Popularity: 4/5                 44.48          100.0
# Popularity Rank : Popularity: 5/5                 48.68          100.0
#
#                                    Count Ratio to Max
# API Feed
# Popularity Rank : Popularity: 1/5                0.34
# Popularity Rank : Popularity: 2/5                0.64
# Popularity Rank : Popularity: 3/5                1.00
# Popularity Rank : Popularity: 4/5                0.90
# Popularity Rank : Popularity: 5/5                0.27

# %%
items2 = pd.merge(items_sm, category_ids_sm
                  , left_on = 'category_id_0', right_on='id_number'
                  , how='left').drop(['id_number', 'short_name'], axis=1)\
    .rename({'name_x':'vendor name', 
             'name_y':'category name'}, axis=1)
items2.shape
# Out:
# (29636, 41)

# %%
items2.columns
# Out:
# Index(['id', 'headline', 'brief_headline', 'summary', 'secondary_summary',
#        'key_attribute', 'brief_notes', 'url', 'display_date',
#        'publish_datetime_ts', 'update_datetime_ts', 'expiration_datetime_ts',
#        'last_verified_datetime_ts', 'editors_choice', 'sponsored', 'expired',
#        'expires_today', 'exclusive', 'searchable', 'hotness', 'call_out',
#        'call_out_comparison', 'sub_call_out', 'Coupon Code', 'category_id_0',
#        'namepath_0', 'ancestor_list_0', 'category_id_1', 'namepath_1',
#        'ancestor_list_1', 'vendor_id', 'vendor name', 'Image path', 'API Feed',
#        'API id_number', '_dt_pulled', 'callout_compare_parse', 'callout_parse',
#        'callout_diff', 'callout_diff_pct', 'category name'],
#       dtype='object')

# %%
vendor_gb = items2.groupby('vendor name').apply(lambda x:api_gb_func(x))\
    .sort_values('Count', ascending=False)
vendor_gb.head(12)
# Out:
#                            Count  # w/ $ callout  Avg Callout Price  \
# vendor name
# Amazon                   15448.0         15448.0              63.41
# eBay                      2781.0          2781.0             225.26
# Macy's                    1179.0          1179.0              64.67
# Home Depot                 952.0           952.0             208.72
# Walmart                    718.0           718.0             112.54
# Woot! An Amazon Company    424.0           424.0             136.72
# Lowe's                     356.0           356.0             207.36
# Wayfair                    277.0           277.0             170.39
# HP                         248.0           248.0             642.87
# Nike                       229.0           229.0              68.17
# MorningSave                215.0           215.0              53.82
# Best Buy                   214.0           214.0             385.31
#
#                          Avg Callout Pct Diff
# vendor name
# Amazon                                  39.86
# eBay                                    40.57
# Macy's                                  61.19
# Home Depot                              28.18
# Walmart                                 40.33
# Woot! An Amazon Company                 45.18
# Lowe's                                  31.40
# Wayfair                                 39.72
# HP                                      19.99
# Nike                                    33.20
# MorningSave                             58.44
# Best Buy                                39.25

# %%
top_vendors = vendor_gb.sort_values('Count', ascending=False)[:10].index.tolist()
top_vendors
# Out:
# ['Amazon',
#  'eBay',
#  "Macy's",
#  'Home Depot',
#  'Walmart',
#  'Woot! An Amazon Company',
#  "Lowe's",
#  'Wayfair',
#  'HP',
#  'Nike']

# %%
cateogry_gb =  items2.groupby('category name').apply(lambda x:api_gb_func(x))\
    .sort_values('Count', ascending=False)
cateogry_gb
# Out:
#                             Count  # w/ $ callout  Avg Callout Price  \
# category name
# Toys & Hobbies             1187.0          1187.0              75.13
# Automotive                  618.0           618.0              47.48
# Home & Garden               591.0           591.0              54.86
# Groceries                   292.0           292.0              17.26
# Bed & Bath                  254.0           254.0             116.88
# Sports & Fitness            209.0           209.0             123.52
# Monitors                    204.0           204.0             276.49
# Patio Furniture             148.0           148.0             237.41
# Clothing & Accessories       90.0            90.0              23.31
# Electronics                  59.0            59.0              66.53
# Gift Cards                   52.0            52.0              55.71
# Office & School Supplies     49.0            49.0              34.91
# Food & Drink                 38.0            38.0              24.81
# Store Events                 25.0            25.0             188.93
# Gaming & Toys                24.0            24.0             140.38
# Health & Beauty              20.0            20.0              48.34
# Movies, TV Shows & Videos    10.0            10.0              32.60
# Travel & Entertainment        7.0             7.0              52.29
# Cell Phones                   5.0             5.0              56.40
# Movies, Music, Books          4.0             4.0              12.72
# Computers                     2.0             2.0             164.50
# Car Rentals                   1.0             1.0             495.00
#
#                            Avg Callout Pct Diff
# category name
# Toys & Hobbies                            40.11
# Automotive                                38.20
# Home & Garden                             37.80
# Groceries                                 36.03
# Bed & Bath                                38.95
# Sports & Fitness                          39.46
# Monitors                                  29.05
# Patio Furniture                           31.92
# Clothing & Accessories                    52.29
# Electronics                               38.80
# Gift Cards                                15.73
# Office & School Supplies                  37.91
# Food & Drink                              37.30
# Store Events                              43.79
# Gaming & Toys                             37.78
# Health & Beauty                           47.64
# Movies, TV Shows & Videos                 55.84
# Travel & Entertainment                    33.65
# Cell Phones                               50.15
# Movies, Music, Books                      68.18
# Computers                                 43.31
# Car Rentals                               23.85

# %%
items2['1'] = 1
items2_sm = items2[items2['vendor name'].isin(top_vendors)]
top_vendor_categories = pd.pivot_table(items2_sm, index = 'category name', columns='vendor name', values='1'
              , aggfunc = np.sum, margins=True)\
    .sort_values('All', ascending=False).head(10)
top_vendor_categories
# Out:
# vendor name       Amazon    HP  Home Depot  Lowe's  Macy's  Nike  Walmart  \
# category name
# All               2575.0  24.0        36.0    34.0    52.0   4.0    131.0
# Toys & Hobbies     833.0   NaN         NaN     2.0    28.0   NaN     70.0
# Automotive         480.0   NaN         3.0     2.0     NaN   NaN     12.0
# Home & Garden      386.0   NaN        13.0     9.0     1.0   NaN     18.0
# Groceries          240.0   NaN         NaN     NaN     1.0   NaN      5.0
# Bed & Bath         176.0   NaN        11.0    10.0     7.0   NaN      2.0
# Sports & Fitness   136.0   NaN         NaN     1.0     4.0   2.0      4.0
# Monitors            76.0  24.0         NaN     NaN     NaN   NaN      3.0
# Patio Furniture     54.0   NaN         7.0     6.0     NaN   NaN      6.0
# Electronics         47.0   NaN         1.0     NaN     NaN   NaN      1.0
#
# vendor name       Wayfair  Woot! An Amazon Company   eBay   All
# category name
# All                  56.0                     70.0  224.0  3206
# Toys & Hobbies        6.0                     18.0   81.0  1038
# Automotive            1.0                      8.0   29.0   535
# Home & Garden        26.0                     11.0   20.0   484
# Groceries             NaN                      5.0    NaN   251
# Bed & Bath           11.0                      8.0    6.0   231
# Sports & Fitness      1.0                      4.0   21.0   173
# Monitors              NaN                      6.0   40.0   149
# Patio Furniture      10.0                      3.0    9.0    95
# Electronics           NaN                      1.0    5.0    55

# %%
amazon_items = items2[items2['vendor name'] == 'Amazon']
non_amazon_items = items2[items2['vendor name'] != 'Amazon']

# %%
amzn_categories = pd.concat({'Count' : amazon_items['category name'].value_counts()
                            ,'Percent' :np.round(100*amazon_items['category name']\
                                                     .value_counts(normalize=True), 2)}
                            , axis=1)
amzn_categories.head(10)
# Out:
#                           Count  Percent
# Toys & Hobbies              833    32.35
# Automotive                  480    18.64
# Home & Garden               386    14.99
# Groceries                   240     9.32
# Bed & Bath                  176     6.83
# Sports & Fitness            136     5.28
# Monitors                     76     2.95
# Patio Furniture              54     2.10
# Electronics                  47     1.83
# Office & School Supplies     33     1.28

# %%
amzn_categories = amazon_items.groupby('category name').apply(lambda x: api_gb_func(x))\
    .sort_values('Avg Callout Pct Diff', ascending=False)
amzn_categories[amzn_categories['Count'] > 20]
# Out:
#                           Count  # w/ $ callout  Avg Callout Price  \
# category name
# Toys & Hobbies            833.0           833.0              46.62
# Bed & Bath                176.0           176.0              52.66
# Sports & Fitness          136.0           136.0              81.44
# Electronics                47.0            47.0              43.00
# Automotive                480.0           480.0              42.02
# Home & Garden             386.0           386.0              36.66
# Patio Furniture            54.0            54.0             167.91
# Office & School Supplies   33.0            33.0              39.49
# Groceries                 240.0           240.0              11.82
# Clothing & Accessories     21.0            21.0              27.53
# Food & Drink               25.0            25.0              16.24
# Monitors                   76.0            76.0             291.64
# Gift Cards                 22.0            22.0              50.86
#
#                           Avg Callout Pct Diff
# category name
# Toys & Hobbies                           40.97
# Bed & Bath                               39.71
# Sports & Fitness                         39.14
# Electronics                              38.50
# Automotive                               38.21
# Home & Garden                            36.31
# Patio Furniture                          35.42
# Office & School Supplies                 34.99
# Groceries                                34.88
# Clothing & Accessories                   34.22
# Food & Drink                             31.70
# Monitors                                 29.40
# Gift Cards                               17.51

# %%
non_amzn_categories = non_amazon_items.groupby('category name').apply(lambda x: api_gb_func(x))\
    .sort_values('Avg Callout Pct Diff', ascending=False)
non_amzn_categories[non_amzn_categories['Count'] > 20]
# Out:
#                         Count  # w/ $ callout  Avg Callout Price  \
# category name
# Clothing & Accessories   69.0            69.0              22.02
# Groceries                52.0            52.0              42.32
# Home & Garden           205.0           205.0              89.11
# Sports & Fitness         73.0            73.0             201.91
# Automotive              138.0           138.0              66.46
# Toys & Hobbies          354.0           354.0             142.21
# Bed & Bath               78.0            78.0             261.79
# Patio Furniture          94.0            94.0             277.34
# Monitors                128.0           128.0             267.48
# Gift Cards               30.0            30.0              59.27
#
#                         Avg Callout Pct Diff
# category name
# Clothing & Accessories                 58.02
# Groceries                              42.22
# Home & Garden                          40.74
# Sports & Fitness                       40.08
# Automotive                             38.17
# Toys & Hobbies                         37.97
# Bed & Bath                             37.22
# Patio Furniture                        29.94
# Monitors                               28.83
# Gift Cards                             14.54

# %% [markdown]
# ## Over time analysis

# %%
import plotly.express as px

# %%
items_sm = items.drop_duplicates(subset=['headline'])
items_sm = items_sm[items_sm['callout_parse'].notnull()]
print(f"Keep {items_sm.shape[0]} ", np.round(100*items_sm.shape[0]/items.shape[0],2))
items_sm['publish_time'] = pd.to_datetime(items_sm['publish_datetime_ts'])
# Out:
# Keep 29636  44.85

# %%
items_sm_time = items_sm.set_index('publish_time') 
time_gb = items_sm_time.groupby(pd.Grouper(freq='D')).apply(lambda x:api_gb_func(x))\
    .reset_index()
time_gb = time_gb[time_gb['Count'] > 0]\
    .sort_values('publish_time')\
    .tail(180) # Last 6  months
time_gb['DOW'] = time_gb['publish_time'].dt.day_name()
time_gb['Weekend_flag'] = time_gb['DOW'].isin(['Saturday','Sunday'])
time_gb
# Out:
#     publish_time  Count  # w/ $ callout  Avg Callout Price  \
# 234   2021-10-18  153.0           153.0             136.15
# 235   2021-10-19  145.0           145.0             138.24
# 236   2021-10-20  129.0           129.0             140.21
# 237   2021-10-21  125.0           125.0             150.78
# 238   2021-10-22  126.0           126.0             201.06
# 239   2021-10-23   29.0            29.0              76.64
# 240   2021-10-24   31.0            31.0              71.32
# 241   2021-10-25  140.0           140.0              86.73
# 242   2021-10-26  130.0           130.0             101.47
# 243   2021-10-27  124.0           124.0              83.28
# 244   2021-10-28  124.0           124.0              99.50
# 245   2021-10-29  118.0           118.0              86.86
# 246   2021-10-30   34.0            34.0              75.72
# 247   2021-10-31   27.0            27.0              40.62
# 248   2021-11-01  107.0           107.0             192.39
# 249   2021-11-02  115.0           115.0             162.04
# 250   2021-11-03  136.0           136.0             116.49
# 251   2021-11-04  122.0           122.0             124.75
# 252   2021-11-05  129.0           129.0             159.02
# 253   2021-11-06   32.0            32.0              83.90
# 254   2021-11-07   27.0            27.0             192.20
# 388   2022-03-21  136.0           136.0             100.58
# 389   2022-03-22  101.0           101.0             140.08
# 390   2022-03-23   93.0            93.0             150.68
# 391   2022-03-24   91.0            91.0             119.03
# 392   2022-03-25   89.0            89.0              73.79
# 393   2022-03-26   28.0            28.0              87.28
# 394   2022-03-27   25.0            25.0              40.16
# 395   2022-03-28  119.0           119.0             113.84
# 396   2022-03-29  112.0           112.0             107.56
# 397   2022-03-30  103.0           103.0              90.78
# 398   2022-03-31   87.0            87.0             161.17
# 399   2022-04-01   97.0            97.0              91.13
# 400   2022-04-02   23.0            23.0              66.87
# 401   2022-04-03   23.0            23.0              50.45
# 402   2022-04-04  109.0           109.0             114.93
# 403   2022-04-05   89.0            89.0             131.78
# 404   2022-04-06  108.0           108.0              98.03
# 405   2022-04-07  104.0           104.0             128.38
# 406   2022-04-08   75.0            75.0             201.73
# 407   2022-04-09   19.0            19.0              75.92
# 408   2022-04-10   20.0            20.0              40.93
# 409   2022-04-11  102.0           102.0              77.85
# 410   2022-04-12  104.0           104.0             178.50
# 411   2022-04-13  116.0           116.0             132.61
# 412   2022-04-14   87.0            87.0             120.60
# 413   2022-04-15   50.0            50.0              94.93
#
#      Avg Callout Pct Diff        DOW  Weekend_flag
# 234                 37.89     Monday         False
# 235                 40.16    Tuesday         False
# 236                 41.11  Wednesday         False
# 237                 38.95   Thursday         False
# 238                 37.24     Friday         False
# 239                 38.32   Saturday          True
# 240                 37.97     Sunday          True
# 241                 40.86     Monday         False
# 242                 37.66    Tuesday         False
# 243                 40.87  Wednesday         False
# 244                 37.97   Thursday         False
# 245                 39.63     Friday         False
# 246                 44.47   Saturday          True
# 247                 42.82     Sunday          True
# 248                 37.32     Monday         False
# 249                 36.48    Tuesday         False
# 250                 40.49  Wednesday         False
# 251                 40.47   Thursday         False
# 252                 40.77     Friday         False
# 253                 46.48   Saturday          True
# 254                 39.67     Sunday          True
# 255                 39.06     Monday         False
# 256                 38.80    Tuesday         False
# 257                 41.39  Wednesday         False
# 258                 40.78   Thursday         False
# 259                 43.44     Friday         False
# 260                 49.06   Saturday          True
# 261                 42.94     Sunday          True
# 262                 42.32     Monday         False
# 263                 41.25    Tuesday         False
# 264                 39.35  Wednesday         False
# 265                 40.03   Thursday         False
# 266                 41.81     Friday         False
# 267                 44.23   Saturday          True
# 268                 44.67     Sunday          True
# 269                 40.72     Monday         False
# 270                 43.53    Tuesday         False
# 271                 42.10  Wednesday         False
# 272                 39.01   Thursday         False
# 273                 40.88     Friday         False
# 274                 40.34   Saturday          True
# 275                 43.59     Sunday          True
# 276                 37.52     Monday         False
# 277                 41.10    Tuesday         False
# 278                 40.53  Wednesday         False
# 279                 40.10   Thursday         False
# 280                 39.74     Friday         False
# 281                 48.02   Saturday          True
# 282                 39.85     Sunday          True
# 283                 43.69     Monday         False
# 284                 37.91    Tuesday         False
# 285                 40.34  Wednesday         False
# 286                 44.49   Thursday         False
# 287                 41.23     Friday         False
# 288                 46.51   Saturday          True
# 289                 45.91     Sunday          True
# 290                 39.03     Monday         False
# 291                 40.44    Tuesday         False
# 292                 44.21  Wednesday         False
# 293                 43.26   Thursday         False
# 294                 41.51     Friday         False
# 295                 49.69   Saturday          True
# 296                 47.15     Sunday          True
# 297                 44.68     Monday         False
# 298                 38.69    Tuesday         False
# 299                 38.61  Wednesday         False
# 300                 38.30   Thursday         False
# 301                 39.29     Friday         False
# 302                 42.08   Saturday          True
# 303                 47.43     Sunday          True
# 304                 44.47     Monday         False
# 305                 36.18    Tuesday         False
# 306                 39.14  Wednesday         False
# 307                 35.85   Thursday         False
# 308                 36.23     Friday         False
# 309                 48.16   Saturday          True
# 310                 42.81     Sunday          True
# 311                 41.49     Monday         False
# 312                 43.71    Tuesday         False
# 313                 39.37  Wednesday         False
# 314                 40.51   Thursday         False
# 315                 44.52     Friday         False
# 316                 45.85   Saturday          True
# 317                 51.20     Sunday          True
# 318                 39.71     Monday         False
# 319                 40.65    Tuesday         False
# 320                 43.44  Wednesday         False
# 321                 43.95   Thursday         False
# 322                 44.28     Friday         False
# 323                 45.93   Saturday          True
# 324                 36.11     Sunday          True
# 325                 45.06     Monday         False
# 326                 41.98    Tuesday         False
# 327                 41.56  Wednesday         False
# 328                 39.90   Thursday         False
# 329                 40.85     Friday         False
# 330                 49.42   Saturday          True
# 331                 44.98     Sunday          True
# 332                 45.46     Monday         False
# 333                 42.61    Tuesday         False
# 334                 41.73  Wednesday         False
# 335                 42.86   Thursday         False
# 336                 42.34     Friday         False
# 337                 46.06   Saturday          True
# 338                 50.64     Sunday          True
# 339                 37.72     Monday         False
# 340                 41.16    Tuesday         False
# 341                 43.06  Wednesday         False
# 342                 42.88   Thursday         False
# 343                 37.12     Friday         False
# 344                 49.75   Saturday          True
# 345                 41.12     Sunday          True
# 346                 39.17     Monday         False
# 347                 36.44    Tuesday         False
# 348                 39.20  Wednesday         False
# 349                 40.20   Thursday         False
# 350                 41.78     Friday         False
# 351                 44.20   Saturday          True
# 352                 50.10     Sunday          True
# 353                 37.59     Monday         False
# 354                 39.87    Tuesday         False
# 355                 41.01  Wednesday         False
# 356                 41.43   Thursday         False
# 357                 44.02     Friday         False
# 358                 46.80   Saturday          True
# 359                 43.37     Sunday          True
# 360                 38.94     Monday         False
# 361                 40.26    Tuesday         False
# 362                 41.46  Wednesday         False
# 363                 42.07   Thursday         False
# 364                 40.34     Friday         False
# 365                 45.31   Saturday          True
# 366                 45.84     Sunday          True
# 367                 36.23     Monday         False
# 368                 39.55    Tuesday         False
# 369                 37.20  Wednesday         False
# 370                 38.42   Thursday         False
# 371                 39.15     Friday         False
# 372                 43.94   Saturday          True
# 373                 44.23     Sunday          True
# 374                 41.89     Monday         False
# 375                 37.16    Tuesday         False
# 376                 39.06  Wednesday         False
# 377                 43.77   Thursday         False
# 378                 46.54     Friday         False
# 379                 42.32   Saturday          True
# 380                 51.27     Sunday          True
# 381                 42.83     Monday         False
# 382                 38.89    Tuesday         False
# 383                 40.45  Wednesday         False
# 384                 35.92   Thursday         False
# 385                 40.01     Friday         False
# 386                 38.08   Saturday          True
# 387                 30.27     Sunday          True
# 388                 37.92     Monday         False
# 389                 35.03    Tuesday         False
# 390                 31.96  Wednesday         False
# 391                 38.66   Thursday         False
# 392                 44.89     Friday         False
# 393                 40.32   Saturday          True
# 394                 48.52     Sunday          True
# 395                 38.56     Monday         False
# 396                 41.95    Tuesday         False
# 397                 37.35  Wednesday         False
# 398                 37.29   Thursday         False
# 399                 41.63     Friday         False
# 400                 45.15   Saturday          True
# 401                 49.59     Sunday          True
# 402                 41.22     Monday         False
# 403                 38.30    Tuesday         False
# 404                 45.44  Wednesday         False
# 405                 43.93   Thursday         False
# 406                 48.04     Friday         False
# 407                 43.83   Saturday          True
# 408                 38.66     Sunday          True
# 409                 40.14     Monday         False
# 410                 38.22    Tuesday         False
# 411                 37.83  Wednesday         False
# 412                 40.84   Thursday         False
# 413                 38.75     Friday         False

# %%
px.scatter(time_gb, 'publish_time', 'Count'
           , color='Weekend_flag'
          , trendline='ols')
# Out:
# <div>                            <div id="7913e81b-92dc-4b55-af1f-2464d7263bee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7913e81b-92dc-4b55-af1f-2464d7263bee")) {                    Plotly.newPlot(                        "7913e81b-92dc-4b55-af1f-2464d7263bee",                        [{"hovertemplate":"Weekend_flag=False<br>publish_time=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"False","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":["2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-15T00:00:00","2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-26T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00"],"xaxis":"x","y":[153.0,145.0,129.0,125.0,126.0,140.0,130.0,124.0,124.0,118.0,107.0,115.0,136.0,122.0,129.0,161.0,144.0,159.0,133.0,94.0,173.0,149.0,143.0,121.0,121.0,157.0,124.0,112.0,137.0,107.0,134.0,117.0,140.0,128.0,133.0,118.0,125.0,142.0,128.0,124.0,139.0,139.0,111.0,118.0,131.0,156.0,125.0,109.0,100.0,84.0,87.0,102.0,92.0,110.0,101.0,96.0,107.0,139.0,101.0,122.0,139.0, ...

# %%
px.scatter(time_gb, 'publish_time', 'Avg Callout Price'
          , trendline='ols')
# Out:
# <div>                            <div id="0af8f560-0aa3-4267-b883-2524cf3d33f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0af8f560-0aa3-4267-b883-2524cf3d33f1")) {                    Plotly.newPlot(                        "0af8f560-0aa3-4267-b883-2524cf3d33f1",                        [{"hovertemplate":"publish_time=%{x}<br>Avg Callout Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-23T00:00:00","2021-10-24T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-10-30T00:00:00","2021-10-31T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-07T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-13T00:00:00","2021-11-14T00:00:00","2021-11-15T00:00:00","2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-20T00:00:00","2021-11-21T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-26T00:00:00","2021-11-27T00:00:00","2021-11-28T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-04T00:00:00","2021-12-05T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-11T00:00:00","2021-12-12T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-18T00:00:00","2021-12-19T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2 ...

# %%
px.scatter(time_gb, 'publish_time', 'Avg Callout Pct Diff'
          , trendline='ols')
# Out:
# <div>                            <div id="dee17576-db6c-4167-b1bc-c6477798c03a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dee17576-db6c-4167-b1bc-c6477798c03a")) {                    Plotly.newPlot(                        "dee17576-db6c-4167-b1bc-c6477798c03a",                        [{"hovertemplate":"publish_time=%{x}<br>Avg Callout Pct Diff=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-23T00:00:00","2021-10-24T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-10-30T00:00:00","2021-10-31T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-07T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-13T00:00:00","2021-11-14T00:00:00","2021-11-15T00:00:00","2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-20T00:00:00","2021-11-21T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-26T00:00:00","2021-11-27T00:00:00","2021-11-28T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-04T00:00:00","2021-12-05T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-11T00:00:00","2021-12-12T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-18T00:00:00","2021-12-19T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00" ...

# %%
items['_dt_pulled'].max()
# Out:
# '2022-04-15 15:37'

# %%
items['_dt_pulled'].min()
# Out:
# '2021-06-18 18:10'

# %%
items['date'] = items['_dt_pulled'].str[:10]
